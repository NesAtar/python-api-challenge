# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 612

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#url = "https://api.openweathermap.org/data/2.5/weather?"
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url = f"{url}q={city}&appid={weather_api_key}&units={units}"
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port mathurin
# Processing Record 2 of Set 1 | rafraf
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | east london
# Processing Record 5 of Set 1 | lata
# Processing Record 6 of Set 1 | grytviken
# Processing Record 7 of Set 1 | souillac
# Processing Record 8 of Set 1 | edinburgh of the seven seas
# Processing Record 9 of Set 1 | whitehorse
# Processing Record 10 of Set 1 | tiksi
# Processing Record 11 of Set 1 | xinqing
# Processing Record 12 of Set 1 | waitangi
# Processing Record 13 of Set 1 | anadyr
# Processing Record 14 of Set 1 | birpur
# Processing Record 15 of Set 1 | inga
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | muscatine
# Processing Record 18 of Set 1 | ewing
# Processing Record 19 of Set 1 | remire-montjoly
# Processing Record 20 of Set 1 | port-aux-francais
# Processing Record 21 of Set 1 | west island
# Processing Record 22 of Set 1 | ilulissat
# Processing Record 23 of Set 1 | port elizabeth
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | invercargill
# Processing Record 26 of Set 1 | constantia
# Processing Record 27 of Set 1 | abbeville
# Processing Record 28 of Set 1 | nar'yan-mar
# Processing Record 29 of Set 1 | salgotarjan
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | lebu
# Processing Record 32 of Set 1 | ta`u
# Processing Record 33 of Set 1 | kingston
# Processing Record 34 of Set 1 | lipovtsy
# Processing Record 35 of Set 1 | iskateley
# Processing Record 36 of Set 1 | vorgashor
# Processing Record 37 of Set 1 | baneasa
# Processing Record 38 of Set 1 | okoneshnikovo
# Processing Record 39 of Set 1 | portland
# Processing Record 40 of Set 1 | fale old settlement
# Processing Record 41 of Set 1 | novyy urengoy
# Processing Record 42 of Set 1 | colonia
# Processing Record 43 of Set 1 | zyryanovsk
# Processing Record 44 of Set 1 | holualoa
# Processing Record 45 of Set 1 | kupang
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | badger
# Processing Record 48 of Set 1 | isafjordur
# Processing Record 49 of Set 1 | taltal
# Processing Record 50 of Set 1 | hawaiian paradise park
# Processing Record 0 of Set 2 | damongo
# City not found. Skipping...
# Processing Record 1 of Set 2 | nadym
# Processing Record 2 of Set 2 | talcahuano
# Processing Record 3 of Set 2 | sitka
# Processing Record 4 of Set 2 | bethanie
# Processing Record 5 of Set 2 | haiku-pauwela
# Processing Record 6 of Set 2 | blackmans bay
# Processing Record 7 of Set 2 | grand falls-windsor
# Processing Record 8 of Set 2 | karratha
# Processing Record 9 of Set 2 | kalabo
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 12 of Set 2 | lospalos
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | talnakh
# Processing Record 15 of Set 2 | champerico
# Processing Record 16 of Set 2 | polyarnyy
# Processing Record 4 of Set 5 | jamestown
# Processing Record 5 of Set 5 | hamilton
# Processing Record 6 of Set 5 | bernay
# Processing Record 7 of Set 5 | chonchi
# Processing Record 8 of Set 5 | iwanai
# Processing Record 9 of Set 5 | derinkuyu
# Processing Record 10 of Set 5 | villa yapacani
# Processing Record 11 of Set 5 | fredericksburg
# Processing Record 12 of Set 5 | slave lake
# Processing Record 13 of Set 5 | luena
# Processing Record 14 of Set 5 | qamdo
# Processing Record 15 of Set 5 | at taj
# Processing Record 16 of Set 5 | ankazobe
# Processing Record 17 of Set 5 | nguigmi
# Processing Record 18 of Set 5 | thompson
# Processing Record 19 of Set 5 | ust'-kulom
# Processing Record 20 of Set 5 | coquimbo
# Processing Record 21 of Set 5 | pontes e lacerda
# Processing Record 22 of Set 5 | sake
# Processing Record 23 of Set 5 | pocone
# Processing Record 24 of Set 5 | jamaame
# Processing Record 25 of Set 5 | songyuan
# Processing Record 26 of Set 5 | aswan
# Processing Record 27 of Set 5 | porto novo
# Processing Record 28 of Set 5 | huambo
# Processing Record 29 of Set 5 | alaghsas
# Processing Record 30 of Set 5 | alice springs
# Processing Record 31 of Set 5 | mabai
# Processing Record 32 of Set 5 | linxia chengguanzhen
# Processing Record 33 of Set 5 | howrah
# Processing Record 34 of Set 5 | mugango
# Processing Record 35 of Set 5 | ke-macina
# Processing Record 36 of Set 5 | kwang binh
# Processing Record 37 of Set 5 | tobi village
# City not found. Skipping...
# Processing Record 38 of Set 5 | al jawf
# Processing Record 39 of Set 5 | pekanbaru
# Processing Record 40 of Set 5 | tazovsky
# Processing Record 41 of Set 5 | darazo
# Processing Record 42 of Set 5 | broken hill
# Processing Record 43 of Set 5 | kone
# Processing Record 44 of Set 5 | robertsport
# Processing Record 45 of Set 5 | pakse
# Processing Record 46 of Set 5 | pyhajarvi
# Processing Record 47 of Set 5 | ancud
# Processing Record 48 of Set 5 | udachny
# Processing Record 49 of Set 5 | valparaiso
# Processing Record 0 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 1 of Set 6 | san antonio de pale
# Processing Record 2 of Set 6 | coco
# Processing Record 3 of Set 6 | port lincoln
# Processing Record 4 of Set 6 | afaahiti
# Processing Record 5 of Set 6 | antsiranana
# Processing Record 6 of Set 6 | howard springs
# Processing Record 7 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 8 of Set 6 | staunton
# Processing Record 9 of Set 6 | aripuana
# Processing Record 10 of Set 6 | trenggalek
# Processing Record 11 of Set 6 | oneonta
# Processing Record 12 of Set 6 | santa terezinha
# Processing Record 13 of Set 6 | xianju
# Processing Record 14 of Set 6 | flin flon
# Processing Record 15 of Set 6 | montijo
# Processing Record 16 of Set 6 | makarov
# Processing Record 17 of Set 6 | colby
# Processing Record 18 of Set 6 | carutapera
# Processing Record 19 of Set 6 | am djarass
# City not found. Skipping...
# Processing Record 20 of Set 6 | withernsea
# Processing Record 21 of Set 6 | san luis de la loma
# Processing Record 22 of Set 6 | lorengau
# Processing Record 23 of Set 6 | sao jose dos pinhais
# Processing Record 24 of Set 6 | taghazout
# Processing Record 25 of Set 6 | sena madureira
# Processing Record 26 of Set 6 | ntoum
# Processing Record 27 of Set 6 | freetown
# Processing Record 28 of Set 6 | smithers
# Processing Record 29 of Set 6 | kandalaksha
# Processing Record 30 of Set 6 | mutuali
# Processing Record 31 of Set 6 | utrik
# Processing Record 32 of Set 6 | kiunga
# Processing Record 33 of Set 6 | namikupa
# Processing Record 34 of Set 6 | tsiombe
# Processing Record 35 of Set 6 | west bay
# Processing Record 36 of Set 6 | naze
# Processing Record 37 of Set 6 | ban phan don
# Processing Record 38 of Set 6 | amga
# Processing Record 39 of Set 6 | gornozavodsk
# Processing Record 40 of Set 6 | khorixas
# Processing Record 41 of Set 6 | jayapura
# Processing Record 42 of Set 6 | inarajan village
# Processing Record 43 of Set 6 | port saint john's
# Processing Record 44 of Set 6 | prince rupert
# Processing Record 45 of Set 6 | lupane
# Processing Record 46 of Set 6 | laojunmiao
# Processing Record 47 of Set 6 | ponferrada
# Processing Record 48 of Set 6 | robore
# Processing Record 49 of Set 6 | newman
# Processing Record 0 of Set 7 | takamaka
# City not found. Skipping...
# Processing Record 1 of Set 7 | nouadhibou
# Processing Record 2 of Set 7 | zhezqazghan
# Processing Record 3 of Set 7 | bemidji
# Processing Record 4 of Set 7 | ghanzi
# Processing Record 5 of Set 7 | cedeira
# Processing Record 6 of Set 7 | nyurba
# Processing Record 7 of Set 7 | cortez
# Processing Record 8 of Set 7 | meiganga
# Processing Record 9 of Set 7 | vila franca do campo
# Processing Record 10 of Set 7 | misratah
# Processing Record 11 of Set 7 | banska bystrica
# Processing Record 12 of Set 7 | tazacorte
# Processing Record 13 of Set 7 | kirakira
# Processing Record 14 of Set 7 | bom jesus
# Processing Record 15 of Set 7 | lufilufi
# Processing Record 16 of Set 7 | la'ie
# Processing Record 17 of Set 7 | bayganin
# Processing Record 18 of Set 7 | namdrik
# Processing Record 19 of Set 7 | visby
# Processing Record 20 of Set 7 | gananoque
# Processing Record 21 of Set 7 | nahrin
# Processing Record 22 of Set 7 | igdir
# Processing Record 23 of Set 7 | rio san juan
# Processing Record 24 of Set 7 | ilagan
# Processing Record 25 of Set 7 | melito di porto salvo
# Processing Record 26 of Set 7 | kani keli
# Processing Record 27 of Set 7 | dwarka
# Processing Record 28 of Set 7 | saint-philippe
# Processing Record 29 of Set 7 | new norfolk
# Processing Record 30 of Set 7 | antofagasta
# Processing Record 31 of Set 7 | baiti
# Processing Record 32 of Set 7 | alamogordo
# Processing Record 33 of Set 7 | kargasok
# Processing Record 34 of Set 7 | taro
# Processing Record 35 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record
# Processing Record 9 of Set 9 | boulsa
# Processing Record 10 of Set 9 | burang
# Processing Record 11 of Set 9 | flying fish cove
# Processing Record 12 of Set 9 | woodstock
# Processing Record 13 of Set 9 | mount pearl
# Processing Record 14 of Set 9 | staryye ozinki
# Processing Record 15 of Set 9 | palmer
# Processing Record 16 of Set 9 | luwingu
# Processing Record 17 of Set 9 | bogo
# Processing Record 18 of Set 9 | kose
# Processing Record 19 of Set 9 | itanagar
# Processing Record 20 of Set 9 | carauari
# Processing Record 21 of Set 9 | argostolion
# Processing Record 22 of Set 9 | pitimbu
# Processing Record 23 of Set 9 | cabedelo
# Processing Record 24 of Set 9 | bardsir
# Processing Record 25 of Set 9 | easton
# Processing Record 26 of Set 9 | hasaki
# Processing Record 27 of Set 9 | saint-joseph
# Processing Record 28 of Set 9 | nema
# Processing Record 29 of Set 9 | agat village
# Processing Record 30 of Set 9 | tabou
# Processing Record 31 of Set 9 | mount hagen
# Processing Record 32 of Set 9 | phillip island
# Processing Record 33 of Set 9 | tangalle
# Processing Record 34 of Set 9 | kapuskasing
# Processing Record 35 of Set 9 | pasuquin
# Processing Record 36 of Set 9 | talara
# Processing Record 37 of Set 9 | tessaoua
# Processing Record 38 of Set 9 | touros
# Processing Record 39 of Set 9 | sarina
# Processing Record 40 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 41 of Set 9 | vancleave
# Processing Record 42 of Set 9 | komsomolsk-on-amur
# Processing Record 43 of Set 9 | gao
# Processing Record 44 of Set 9 | baykal'sk
# Processing Record 45 of Set 9 | khash
# Processing Record 46 of Set 9 | matoury
# Processing Record 47 of Set 9 | ghat
# Processing Record 48 of Set 9 | pointe-noire
# Processing Record 49 of Set 9 | zag
# Processing Record 0 of Set 10 | peniche
# Processing Record 1 of Set 10 | yefremov
# Processing Record 2 of Set 10 | sao vicente
# Processing Record 3 of Set 10 | yerofey pavlovich
# Processing Record 4 of Set 10 | soure
# Processing Record 5 of Set 10 | mount isa
# Processing Record 6 of Set 10 | jinghong
# Processing Record 7 of Set 10 | jumla
# Processing Record 8 of Set 10 | erenhot
# Processing Record 9 of Set 10 | sola
# Processing Record 10 of Set 10 | bomdila
# Processing Record 11 of Set 10 | beihai
# Processing Record 12 of Set 10 | bugul'ma
# Processing Record 13 of Set 10 | opuwo
# Processing Record 14 of Set 10 | la passe
# Processing Record 15 of Set 10 | wanning
# Processing Record 16 of Set 10 | mount gambier
# Processing Record 17 of Set 10 | maceio
# Processing Record 18 of Set 10 | port isabel
# Processing Record 19 of Set 10 | pokhara
# Processing Record 20 of Set 10 | kenai
# Processing Record 21 of Set 10 | susuman
# Processing Record 22 of Set 10 | sur
# Processing Record 23 of Set 10 | kailua-kona
# Processing Record 24 of Set 10 | zheshart
# Processing Record 25 of Set 10 | margherita
# Processing Record 26 of Set 10 | aksu
# Processing Record 27 of Set 10 | inirida
# Processing Record 28 of Set 10 | shache
# Processing Record 29 of Set 10 | tolanaro
# Processing Record 30 of Set 10 | bougouni
# Processing Record 31 of Set 10 | mazagao
# Processing Record 32 of Set 10 | kamwenge
# Processing Record 33 of Set 10 | conception bay south
# Processing Record 34 of Set 10 | kyshtovka
# Processing Record 35 of Set 10 | don luan
# Processing Record 36 of Set 10 | al ghayzah
# Processing Record 37 of Set 10 | midvagur
# Processing Record 38 of Set 10 | gazojak
# Processing Record 39 of Set 10 | lamba
# Processing Record 40 of Set 10 | vuktyl
# Processing Record 41 of Set 10 | cole harbour
# Processing Record 42 of Set 10 | kurtamysh
# Processing Record 43 of Set 10 | chapaev
# Processing Record 44 of Set 10 | broome
# Processing Record 45 of Set 10 | mount horeb
# Processing Record 46 of Set 10 | byford
# Processing Record 47 of Set 10 | hammerfest
# Processing Record 48 of Set 10 | kimbe
# Processing Record 49 of Set 10 | terrace
# Processing Record 0 of Set 11 | yuzhno-kurilsk
# Processing Record 1 of Set 11 | puerto baquerizo moreno
# Processing Record 2 of Set 11 | al mijlad
# Processing Record 3 of Set 11 | kunming
# Processing Record 4 of Set 11 | corinto
# Processing Record 5 of Set 11 | lazaro cardenas
# Processing Record 6 of Set 11 | hirara
# Processing Record 7 of Set 11 | shabqadar
# Processing Record 8 of Set 11 | namtsy
# Processing Record 9 of Set 11 | kambove
# Processing Record 10 of Set 11 | troitskoye
# Processing Record 11 of Set 11 | bantogon
# Processing Record 12 of Set 11 | vrangel'
# Processing Record 13 of Set 11 | dixon
# Processing Record 14 of Set 11 | ishikawa
# Processing Record 15 of Set 11 | azemmour
# Processing Record 16 of Set 11 | apple valley
# Processing Record 17 of Set 11 | mili
# Processing Record 18 of Set 11 | camocim
# Processing Record 19 of Set 11 | la villa del rosario
# Processing Record 20 of Set 11 | dryden
# Processing Record 21 of Set 11 | santa sylvina
# Processing Record 22 of Set 11 | camapua
# Processing Record 23 of Set 11 | port augusta
# Processing Record 24 of Set 11 | 'izbat al burj
# City not found. Skipping...
# Processing Record 25 of Set 11 | salavan
# Processing Record 26 of Set 11 | mwinilunga
# Processing Record 27 of Set 11 | inyonga
# Processing Record 28 of Set 11 | melekeok village
# Processing Record 29 of Set 11 | batouri
# Processing Record 30 of Set 11 | lompoc
# Processing Record 31 of Set 11 | northam
# Processing Record 32 of Set 11 | coxim
# Processing Record 33 of Set 11 | nizhneangarsk
# Processing Record 34 of Set 11 | butterworth
# Processing Record 35 of Set 11 | yeed
# Processing Record 36 of Set 11 | gaspe
# Processing Record 37 of Set 11 | bangassou
# Processing Record 38 of Set 11 | tlalixtac de cabrera
# Processing Record 39 of Set 11 | at-bashi
# Processing Record 40 of Set 11 | were ilu
# Processing Record 41 of Set 11 | acapulco de juarez
# Processing Record 42 of Set 11 | nuku'alofa
# Processing Record 43 of Set 11 | alexandria
# Processing Record 44 of Set 11 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 45 of Set 11 | vilyuchinsk
# Processing Record 46 of Set 11 | peace river
# Processing Record 47 of Set 11 | bitam
# Processing Record 48 of Set 11 | heroica guaymas
# Processing Record 49 of Set 11 | okha
# Processing Record 0 of Set 12 | north bay
# Processing Record 1 of Set 12 | itoman
# Processing Record 2 of Set 12 | vokhtoga
# Processing Record 3 of Set 12 | daru
# Processing Record 4 of Set 12 | esmeraldas
# Processing Record 5 of Set 12 | greymouth
# Processing Record 6 of Set 12 | yangor
# City not found. Skipping...
# Processing Record 7 of Set 12 | placido de castro
# Processing Record 8 of Set 12 | rio de janeiro
# Processing Record 9 of Set 12 | las tablas
# Processing Record 10 of Set 12 | mountain home
# Processing Record 11 of Set 12 | hays
# Processing Record 12 of Set 12 | camana
# Processing Record 13 of Set 12 | januaria
# Processing Record 14 of Set 12 | 'ain el bell
# Processing Record 15 of Set 12 | mooirivier
# Processing Record 16 of Set 12 | comodoro rivadavia
# Processing Record 17 of Set 12 | val-d'or
# Processing Record 18 of Set 12 | hadibu
# Processing Record 19 of Set 12 | realico
# Processing Record 20 of Set 12 | vijayawada
# Processing Record 21 of Set 12 | mangaratiba
# Processing Record 22 of Set 12 | nuuk
# Processing Record 23 of Set 12 | gelemso
# Processing Record 24 of Set 12 | holma
# Processing Record 25 of Set 12 | livramento do brumado
# Processing Record 26 of Set 12 | ryotsu-minato
# Processing Record 27 of Set 12 | santa elena de uairen
# Processing Record 28 of Set 12 | lobujya
# Processing Record 29 of Set 12 | plakhtiyivka
# Processing Record 30 of Set 12 | anloga
# Processing Record 31 of Set 12 | dukhovnitskoye
# Processing Record 32 of Set 12 | antalaha
# Processing Record 33 of Set 12 | firuzabad
# Processing Record 34 of Set 12 | majie
# Processing Record 35 of Set 12 | ndele
# Processing Record 36 of Set 12 | bac lieu
# Processing Record 37 of Set 12 | quesnel
# Processing Record 38 of Set 12 | la romana
# Processing Record 39 of Set 12 | kapit
# Processing Record 40 of Set 12 | fuyang
# Processing Record 41 of Set 12 | santona
# Processing Record 42 of Set 12 | sambava
# Processing Record 43 of Set 12 | capo d'orlando
# Processing Record 44 of Set 12 | nadi
# Processing Record 45 of Set 12 | payyannur
# Processing Record 46 of Set 12 | ulladulla
# Processing Record 47 of Set 12 | mizdah
# Processing Record 48 of Set 12 | cam pha mines
# Processing Record 49 of Set 12 | yekaterinoslavka
# Processing Record 0 of Set 13 | augusto correa
# Processing Record 1 of Set 13 | heber city
# Processing Record 2 of Set 13 | sidi salim
# Processing Record 3 of Set 13 | great falls
# Processing Record 4 of Set 13 | north ward
# Processing Record 5 of Set 13 | south hedland
# Processing Record 6 of Set 13 | nizhniy odes
# Processing Record 7 of Set 13 | podgorenskiy
# Processing Record 8 of Set 13 | yeniseysk
# Processing Record 9 of Set 13 | shimanovsk
# Processing Record 10 of Set 13 | manta
# Processing Record 11 of Set 13 | vallenar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Countcity_data_df.count()
city_data_df.count()
# Out:
# City          589
# Lat           589
# Lng           589
# Max Temp      589
# Humidity      589
# Cloudiness    589
# Wind Speed    589
# Country       589
# Date          589
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port mathurin -19.6833   63.4167     25.66        80          26
# 1         rafraf  37.1904   10.1837     18.17        41         100
# 2      adamstown -25.0660 -130.1015     22.27        75           0
# 3    east london -33.0153   27.9116     19.60        79          96
# 4           lata  40.1629   -8.3327      6.15        92           0
#
#    Wind Speed Country        Date
# 0        6.14      MU  1701482651
# 1        4.32      TN  1701482651
# 2        5.24      PN  1701482651
# 3        6.17      ZA  1701482652
# 4        0.54      PT  1701482652

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port mathurin -19.6833   63.4167     25.66        80          26
# 1               rafraf  37.1904   10.1837     18.17        41         100
# 2            adamstown -25.0660 -130.1015     22.27        75           0
# 3          east london -33.0153   27.9116     19.60        79          96
# 4                 lata  40.1629   -8.3327      6.15        92           0
#
#          Wind Speed Country        Date
# City_ID
# 0              6.14      MU  1701482651
# 1              4.32      TN  1701482651
# 2              5.24      PN  1701482651
# 3              6.17      ZA  1701482652
# 4              0.54      PT  1701482652

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def create_linear_regression_plot(x_data, y_data, x_label, y_label, title, output_filename):
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x_data, y_data)
    regress_values = slope * x_data + intercept

    # Create a scatter plot
    plt.scatter(x_data, y_data, label='Data')

    # Plot the linear regression line
    plt.plot(x_data, regress_values, color='red', label='Linear Regression')

    # Set plot labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)

    # Display the regression equation on the plot
    equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    plt.annotate(equation, (x_data.min(), y_data.max()), fontsize=12, color="red")

    # Show legend
    plt.legend()

    # Save the figure
    plt.savefig(output_filename)

    # Show plot
    plt.show()

# %%
#city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            rafraf  37.1904   10.1837     18.17        41         100
# 4              lata  40.1629   -8.3327      6.15        92           0
# 8        whitehorse  60.7161 -135.0538    -11.57        92          40
# 9             tiksi  71.6872  128.8694    -29.19        98         100
# 10          xinqing  48.2333  129.5000    -11.54        77         100
#
#          Wind Speed Country        Date
# City_ID
# 1              4.32      TN  1701482651
# 4              0.54      PT  1701482652
# 8              1.03      CA  1701482653
# 9              2.49      RU  1701482653
# 10             2.75      CN  1701482653

# %%
# city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port mathurin -19.6833   63.4167     25.66        80          26
# 2            adamstown -25.0660 -130.1015     22.27        75           0
# 3          east london -33.0153   27.9116     19.60        79          96
# 5            grytviken -54.2811  -36.5092      2.27        81          23
# 6             souillac -20.5167   57.5167     23.21        94          75
#
#          Wind Speed Country        Date
# City_ID
# 0              6.14      MU  1701482651
# 2              5.24      PN  1701482651
# 3              6.17      ZA  1701482652
# 5              5.37      GS  1701482362
# 6              1.54      MU  1701482652

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

# Define the x and y data
x_data = northern_hemi_df["Lat"]
y_data = northern_hemi_df["Max Temp"]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x_data, y_data)

# Calculate the regression line
regress_values = slope * x_data + intercept

# Plot the scatter plot and regression line
plt.scatter(x_data, y_data)
plt.plot(x_data, regress_values, color="red", label="Linear Regression")

# Set plot labels and title
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")
plt.title("Northern Hemisphere - Max Temperature vs. Latitude Linear Regression")

# Add the regression equation to the plot
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(equation, (x_data.min(), y_data.max()), fontsize=12, color="red")

# Display the plot
plt.legend()
plt.show()

# %%
# Linear regression on Southern Hemisphere

# Define the x and y data
x_data = southern_hemi_df["Lat"]
y_data = southern_hemi_df["Max Temp"]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x_data, y_data)

# Calculate the regression line
regress_values = slope * x_data + intercept

# Plot the scatter plot and regression line
plt.scatter(x_data, y_data)
plt.plot(x_data, regress_values, color="red", label="Linear Regression")

# Set plot labels and title
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")
plt.title("Southern Hemisphere - Max Temperature vs. Latitude Linear Regression")

# Add the regression equation to the plot
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(equation, (x_data.min(), y_data.min()), fontsize=12, color="red")

# Display the plot
plt.legend()
plt.show()

# %%
#In conclusion, the linear regression analysis provides valuable insights into the relationship between 
#latitude and maximum temperature in both hemispheres. The observed trends and statistical significance 
#of the relationships suggest that latitude can be a meaningful predictor of maximum temperature.  
#Further research could explore additional variables and refine the analysis for a more comprehensive understanding of 
#temperature patterns

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Define the x and y data
x_data = northern_hemi_df["Lat"]
y_data = northern_hemi_df["Humidity"]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x_data, y_data)

# Calculate the regression line
regress_values = slope * x_data + intercept

# Create a scatter plot
plt.scatter(x_data, y_data, label='Data')

# Plot the linear regression line
plt.plot(x_data, regress_values, color='red', label='Linear Regression')

# Set plot labels and title
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")

# Display the regression equation on the plot
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(equation, (x_data.min(), y_data.max()), fontsize=12, color="red")

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
# Southern Hemisphere

# Define the x and y data
x_data = southern_hemi_df["Lat"]
y_data = southern_hemi_df["Humidity"]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x_data, y_data)

# Calculate the regression line
regress_values = slope * x_data + intercept

# Create a scatter plot
plt.scatter(x_data, y_data, label='Data')

# Plot the linear regression line
plt.plot(x_data, regress_values, color='red', label='Linear Regression')

# Set plot labels and title
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")

# Display the regression equation on the plot
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(equation, (x_data.min(), y_data.min()), fontsize=12, color="red")

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
#In conclusion, the linear regression analyses provide valuable insights into the relationships between 
#latitude and humidity in both hemispheres. The observed trends and statistical significance of the relationships 
#suggest that latitude can be a meaningful predictor of humidity. Further research could explore additional variables and 
#refine the analysis for a more comprehensive understanding of humidity patterns in different hemispheres.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Define the x and y data
x_data = northern_hemi_df["Lat"]
y_data = northern_hemi_df["Cloudiness"]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x_data, y_data)

# Calculate the regression line
regress_values = slope * x_data + intercept

# Create a scatter plot
plt.scatter(x_data, y_data, label='Data')

# Plot the linear regression line
plt.plot(x_data, regress_values, color='red', label='Linear Regression')

# Set plot labels and title
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")

# Display the regression equation on the plot
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(equation, (x_data.min(), y_data.max()), fontsize=12, color="red")

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
# Southern Hemisphere

# Define the x and y data
x_data = southern_hemi_df["Lat"]
y_data = southern_hemi_df["Cloudiness"]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x_data, y_data)

# Calculate the regression line
regress_values = slope * x_data + intercept

# Create a scatter plot
plt.scatter(x_data, y_data, label='Data')

# Plot the linear regression line
plt.plot(x_data, regress_values, color='red', label='Linear Regression')

# Set plot labels and title
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")

# Display the regression equation on the plot
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(equation, (x_data.min(), y_data.max()), fontsize=12, color="red")

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
#The linear regression analyses explores the potential relationships between latitude and cloudiness 
#in both the Northern and Southern Hemispheres. In both the Northern and Southern Hemisphere, the linear regression analysis 
#revealed a [positive/negative] relationship between latitude and cloudiness.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# Define the x and y data
x_data = northern_hemi_df["Lat"]
y_data = northern_hemi_df["Wind Speed"]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x_data, y_data)

# Calculate the regression line
regress_values = slope * x_data + intercept

# Create a scatter plot
plt.scatter(x_data, y_data, label='Data')

# Plot the linear regression line
plt.plot(x_data, regress_values, color='red', label='Linear Regression')

# Set plot labels and title
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression")

# Display the regression equation on the plot
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(equation, (x_data.min(), y_data.max()), fontsize=12, color="red")

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
# Southern Hemisphere

# Define the x and y data
x_data = southern_hemi_df["Lat"]
y_data = southern_hemi_df["Wind Speed"]

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x_data, y_data)

# Calculate the regression line
regress_values = slope * x_data + intercept

# Create a scatter plot
plt.scatter(x_data, y_data, label='Data')

# Plot the linear regression line
plt.plot(x_data, regress_values, color='red', label='Linear Regression')

# Set plot labels and title
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("Southern Hemisphere - Wind Speed vs. Latitude Linear Regression")

# Display the regression equation on the plot
equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
plt.annotate(equation, (x_data.min(), y_data.max()), fontsize=12, color="red")

# Show legend
plt.legend()

# Show plot
plt.show()

# %%
#In both Northern and Southern Hemispheres, the linear regression analysis revealed a positive/negative relationship
#between latitude and wind speed. In Northern and Southern hemispheres; positive/negative slope implies that, on average
#as latitude increases, wind speed tends to increase/decrease.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
